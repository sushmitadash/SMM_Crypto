# %%
import json
import pandas as pd

tweets_data_path = "C:\\Users\\dashs\\Desktop\\tweets.json"

# %%
tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue


print (len(tweets_data))

tweets = pd.DataFrame(tweets_data)
# Out:
# 6218

# %%
tweets.tail()
# Out:
#      contributors coordinates                      created_at  \
# 6213         None        None  Tue Apr 10 02:33:57 +0000 2018
# 6214         None        None  Tue Apr 10 02:33:57 +0000 2018
# 6215         None        None  Tue Apr 10 02:33:58 +0000 2018
# 6216         None        None  Tue Apr 10 02:33:58 +0000 2018
# 6217         None        None  Tue Apr 10 02:33:59 +0000 2018
#
#      display_text_range                                           entities  \
# 6213                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 6214                NaN  {'hashtags': [{'text': 'Cryptocurrency', 'indi...
# 6215                NaN  {'hashtags': [{'text': 'Bitcoin', 'indices': [...
# 6216                NaN  {'hashtags': [{'text': 'Airdrop', 'indices': [...
# 6217                NaN  {'hashtags': [{'text': 'cryptocurrency', 'indi...
#
#                                       extended_entities  \
# 6213                                                NaN
# 6214                                                NaN
# 6215  {'media': [{'id': 983319791061516288, 'id_str'...
# 6216                                                NaN
# 6217                                                NaN
#
#                                          extended_tweet  favorite_count  \
# 6213                                                NaN               0
# 6214                                                NaN               0
# 6215                                                NaN               0
# 6216                                                NaN               0
# 6217  {'full_text': 'Earning #cryptocurrency for sel...               0
#
#       favorited filter_level          ...          reply_count  retweet_count  \
# 6213      False          low          ...                    0              0
# 6214      False          low          ...                    0              0
# 6215      False          low          ...                    0              0
# 6216      False          low          ...                    0              0
# 6217      False          low          ...                    0              0
#
#      retweeted                                   retweeted_status  \
# 6213     False  {'created_at': 'Mon Apr 09 22:58:10 +0000 2018...
# 6214     False                                                NaN
# 6215     False  {'created_at': 'Mon Apr 09 12:25:12 +0000 2018...
# 6216     False  {'created_at': 'Mon Apr 09 18:07:08 +0000 2018...
# 6217     False                                                NaN
#
#                                                  source  \
# 6213  <a href="http://twitter.com" rel="nofollow">Tw...
# 6214  <a href="https://dlvrit.com/" rel="nofollow">d...
# 6215  <a href="http://twitter.com" rel="nofollow">Tw...
# 6216  <a href="http://twitter.com/download/android" ...
# 6217  <a href="http://www.listia.com" rel="nofollow"...
#
#                                                    text   timestamp_ms  \
# 6213  RT @prez_miha: Token sales are still ongoing f...  1523327637535
# 6214  Canadian Barter Platform Introduces Its Own #C...  1523327637975
# 6215  RT @Schuldensuehner: #Bitcoin trades below $7k...  1523327638165
# 6216  RT @ThoriumExchange: #Airdrop is live. \n\n100...  1523327638527
# 6217  Earning #cryptocurrency for selling my stuff o...  1523327639468
#
#      truncated                                               user  \
# 6213     False  {'id': 980415533865615361, 'id_str': '98041553...
# 6214     False  {'id': 625289155, 'id_str': '625289155', 'name...
# 6215     False  {'id': 743452335372894208, 'id_str': '74345233...
# 6216     False  {'id': 3426770897, 'id_str': '3426770897', 'na...
# 6217      True  {'id': 1677111162, 'id_str': '1677111162', 'na...
#
#      withheld_in_countries
# 6213                   NaN
# 6214                   NaN
# 6215                   NaN
# 6216                   NaN
# 6217                   NaN
#
# [5 rows x 36 columns]
